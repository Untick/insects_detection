# %% [markdown]
# <a href="https://colab.research.google.com/github/Untick/insects_detection/blob/Ivanov-Alexander-branch/Yolo8_Foto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive #Подключаем гугл диск

drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
ROOT_DIR = '/content/gdrive/MyDrive/cabbage/data' # Указываем папку где лежит датасет

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolov8n.pt")  # load a pretrained model

# %%
# если уже есть сохраненные веса, то например:
model = YOLO("/content/gdrive/MyDrive/cabbage/runs/detect/train111/weights/best.pt")

# %% [markdown]
# Проверка модели на фото

# %%
import cv2

# %%
# Предикт на картинке

results = model.predict(source="/content/gdrive/MyDrive/cabbage/test/frame2_0077.jpg_transformed_3.jpg", conf=0.40, save=True, show=True)
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
#
# image 1/1 /content/gdrive/MyDrive/cabbage/test/frame2_0077.jpg_transformed_3.jpg: 384x640 8 bads, 365.1ms
# Speed: 13.1ms preprocess, 365.1ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict3

# %%
import matplotlib.pyplot as plt

# Берем то что выше вывелось и подставляем сюда:
image = cv2.imread('/content/runs/detect/predict3/frame2_0077.jpg_transformed_3.jpg')

# отображение изображения
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()
